# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_excel(r"C:\Users\Admin\Machine Learning\houseprice_3.xlsx")
dataset.head(3)
# Out:
#       price  area  bedrooms  bathrooms  stories  parking
# 0  13300000  7420         4          2        3        0
# 1  12250000  8960         4          4        4        0
# 2  12250000  9960         3          2        2        1

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="price",y="area", data=dataset,hue="parking")
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["parking"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=19)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test, y_test)*100
# Out:
# 63.33333333333333

# %%
lr.predict([[12250000, 9960, 3, 2, 2]])
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
